# %% [markdown]
# PYTHON PROGRAMMING: EXPERIMENT 2
#
# NAME: HARSHVARDHAN SINGH PARIHAR
#
# SAP_ID: 590029374

# %%
#1 Check whether the given number is divisible by 3 and 5 both.
n=int(input("Enter a number: "))
if( n%3==0 and n%5==0):
    print(n,"is divisible by 3 and 5 both")
else:
  print("not divisible by 3 or 5")
# Out:
# Enter a number: 15
# 15 is divisible by 3 and 5 both

# %%
#2 Check whether a given number is multiple of five or not.
n=int(input("Enter a number: "))
if(n%5==0):
    print(n,"is a multiple of 5")
else:
    print(n,"is not multiple of 5")
# Out:
# Enter a number: 6454546
# 6454546 is not multiple of 5

# %%
#3 Find the greatest among the two numbers. If numbers are equal than print “numbers are equal”.
a=int(input("Enter the first number:"))
b=int(input("Enter the second number:"))
if(a<b):
  print(b,"is greater than",a)
if(a==b):
  print("numbers are equal")
elif(a>b):
  print(a,"is greater than",b)
# Out:
# Enter the first number:8
# Enter the second number:956
# 956 is greater than 8

# %%
#4 Find the greatest among three numbers assuming no two values are same.
a=int(input("Enter the first number:"))
b=int(input("Enter the second number:"))
c=int(input("Enter the third number:"))
if(a>b and a>c):
    print(a,"is greatest")
elif(b>a and b>c):
    print(b,"is greatest")
else:
    print(c,"is greatest")
# Out:
# Enter the first number:4
# Enter the second number:8
# Enter the third number:1
# 8 is greatest

# %%
#5 Check whether the quadratic equation has real roots or imaginary roots. Display the roots.
import math
import cmath

print("Enter the coefficients of the quadratic equation (ax^2 + bx + c):")
a = float(input("Enter a: "))
b = float(input("Enter b: "))
c = float(input("Enter c: "))
d = (b**2) - (4*a*c)
if d > 0:
    root1 = (-b - math.sqrt(d)) / (2*a)
    root2 = (-b + math.sqrt(d)) / (2*a)
    print(f"The equation has two distinct real roots: {root1} and {root2}")
elif d == 0:
    root = -b / (2*a)
    print(f"The equation has one real (repeated) root: {root}")
else:
    root1 = (-b - cmath.sqrt(d)) / (2*a)
    root2 = (-b + cmath.sqrt(d)) / (2*a)
    print(f"The equation has complex roots: {root1} and {root2}")
# Out:
# Enter the coefficients of the quadratic equation (ax^2 + bx + c):
# Enter a: 5
# Enter b: 96
# Enter c: 102
# The equation has two distinct real roots: -18.071127433818948 and -1.1288725661810517

# %%
#6 Find whether a given year is a leap year or not.
year = int(input("Enter a year: "))

if (year % 4 == 0 and year % 100 != 0) or (year % 400 == 0):
  print(f"{year} is a leap year.")
else:
  print(f"{year} is not a leap year.")
# Out:
# Enter a year: 2000
# 2000 is a leap year.

# %%
#7 Write a program which takes any date as input and display next date of the calendar
day = int(input("Enter the day: "))
month = int(input("Enter the month: "))
year = int(input("Enter the year: "))
print(f"The input date is: {day+1}/{month}/{year}")
# Out:
# Enter the day: 5
# Enter the month: 5
# Enter the year: 2222
# The input date is: 6/5/2222

# %%
#8 Print the grade sheet of a student for the given range of cgpa. Scan marks of five subjects and calculate the percentage.
# Student Grade Sheet Generator

def calculate_grade_sheet():
    print("--- Enter Student Details ---")
    subjects = ["Subject 1", "Subject 2", "Subject 3", "Subject 4", "Subject 5"]
    marks = []
    for sub in subjects:
        while True:
            try:
                m = float(input(f"Enter marks for {sub} (out of 100): "))
                if 0 <= m <= 100:
                    marks.append(m)
                    break
                else:
                    print("Please enter marks between 0 and 100.")
            except ValueError:
                print("Invalid input. Please enter a number.")

    total_marks = sum(marks)
    percentage = total_marks / 5
    cgpa = percentage / 10
    if 0 <= cgpa <= 3.4:
        grade = "F"
    elif 3.5 <= cgpa <= 5.0:
        grade = "C+"
    elif 5.1 <= cgpa <= 6.0:
        grade = "B"
    elif 6.1 <= cgpa <= 7.0:
        grade = "B+"
    elif 7.1 <= cgpa <= 8.0:
        grade = "A"
    elif 8.1 <= cgpa <= 9.0:
        grade = "A+"
    elif 9.1 <= cgpa <= 10.0:
        grade = "O (Outstanding)"
    else:
        grade = "Invalid"
    print("\n" + "="*30)
    print("      STUDENT GRADE SHEET      ")
    print("="*30)
    for i, sub in enumerate(subjects):
        print(f"{sub}: {marks[i]}")
    print("-" * 30)
    print(f"Total Marks: {total_marks}/500")
    print(f"Percentage:  {percentage}%")
    print(f"CGPA:        {cgpa:.2f}")
    print(f"Final Grade: {grade}")
    print("="*30)

if __name__ == "__main__":
    calculate_grade_sheet()
# Out:
# --- Enter Student Details ---
# Enter marks for Subject 1 (out of 100): 90
# Enter marks for Subject 2 (out of 100): 92
# Enter marks for Subject 3 (out of 100): 91
# Enter marks for Subject 4 (out of 100): 95
# Enter marks for Subject 5 (out of 100): 93
#
# ==============================
#       STUDENT GRADE SHEET
# ==============================
# Subject 1: 90.0
# Subject 2: 92.0
# Subject 3: 91.0
# Subject 4: 95.0
# Subject 5: 93.0
# ------------------------------
# Total Marks: 461.0/500
# Percentage:  92.2%
# CGPA:        9.22
# Final Grade: O (Outstanding)
# ==============================
